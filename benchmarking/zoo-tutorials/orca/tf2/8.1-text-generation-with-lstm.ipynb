# %%
from tensorflow import keras
keras.__version__
# Out:
# '2.4.0'

# %% [markdown]
# To start using zoo.orca, we need to first initialize orca context. Here we specify local or distributed mode. In this example, we choose the local mode.

# %%
from zoo.orca import init_orca_context, stop_orca_context
from zoo.orca import OrcaContext

OrcaContext.log_output = True # recommended to set it to True when running Analytics Zoo in Jupyter notebook (this will display terminal's  stdout and stderr in the Jupyter notebook).

cluster_mode = "local"

if cluster_mode == "local":  
    init_orca_context(cluster_mode="local", cores=4) # run in local mode
elif cluster_mode == "k8s":  
    init_orca_context(cluster_mode="k8s", num_nodes=2, cores=2) # run on K8s cluster
elif cluster_mode == "yarn":  
    init_orca_context(cluster_mode="yarn-client", num_nodes=2, cores=2) # run on Hadoop YARN cluster

# %% [markdown]
# # Text generation with LSTM
# This notebook contains the code samples found in Chapter 8, Section 1 of Deep Learning with Python. Note that the original text features far more content, in particular further explanations and figures: in this notebook, you will only find source code and related comments.
#
# -----------------------------------------
#
# [...]
#
# ## Implementing character-level LSTM text generation
# Let's put these ideas in practice in a Keras implementation. The first thing we need is a lot of text data that we can use to learn a language model. You could use any sufficiently large text file or set of text files -- Wikipedia, the Lord of the Rings, etc. In this example we will use some of the writings of Nietzsche, the late-19th century German philosopher (translated to English). The language model we will learn will thus be specifically a model of Nietzsche's writing style and topics of choice, rather than a more generic model of the English language.
#
# ## Preparing the data
# Let's start by downloading the corpus and converting it to lowercase:

# %%
import numpy as np

path = keras.utils.get_file(
    'nietzsche.txt',
    origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
text = open(path).read().lower()
print('Corpus length:', len(text))
# Out:
# Corpus length: 600893

# %% [markdown]
# Next, we will extract partially-overlapping sequences of length maxlen, one-hot encode them and pack them in a 3D Numpy array `x` of shape `(sequences, maxlen, unique_characters)`. Simultaneously, we prepare a array `y` containing the corresponding targets: the one-hot encoded characters that come right after each extracted sequence.

# %%
# Length of extracted character sequences
maxlen = 60

# We sample a new sequence every `step` characters
step = 3

# This holds our extracted sequences
sentences = []

# This holds the targets (the follow-up characters)
next_chars = []

for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('Number of sequences:', len(sentences))

# List of unique characters in the corpus
chars = sorted(list(set(text)))
print('Unique characters:', len(chars))
# Dictionary mapping unique characters to their index in `chars`
char_indices = dict((char, chars.index(char)) for char in chars)

# Next, one-hot encode the characters into binary arrays.
print('Vectorization...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# Number of sequences: 200278
# Unique characters: 57
# Vectorization...

# %%
x.shape
# Out:
# (200278, 60, 57)

# %%
y.shape
# Out:
# (200278, 57)

# %% [markdown]
# ## Building the network
# Our network is a single LSTM layer followed by a Dense classifier and softmax over all possible characters. But let us note that recurrent neural networks are not the only way to do sequence data generation; 1D convnets also have proven extremely successful at it in recent times. Since our targets are one-hot encoded, we will use `categorical_crossentropy` as the loss to train the model:

# %%
from tensorflow.keras import layers

def build_model(config):
    model = keras.Sequential()
    model.add(layers.LSTM(128, input_shape=(maxlen, len(chars))))
    model.add(layers.Dense(len(chars), activation='softmax'))
    optimizer = keras.optimizers.RMSprop(lr=0.01)
    model.compile(loss='categorical_crossentropy', optimizer=optimizer)
    return model

# %% [markdown]
# We also create a `data_creator` function that help us import the data into the orca estimator.

# %%
import tensorflow as tf

def train_data_creator(config, batch_size):
    dataset = tf.data.Dataset.from_tensor_slices((x, y))
    dataset = dataset.repeat()
    dataset = dataset.shuffle(1000)
    dataset = dataset.batch(config["batch_size"])
    return dataset

# %% [markdown]
# Training the language model and sampling from it
# Given a trained model and a seed text snippet, we generate new text by repeatedly:
#
# * 1) Drawing from the model a probability distribution over the next character given the text available so far
# * 2) Reweighting the distribution to a certain "temperature"
# * 3) Sampling the next character at random according to the reweighted distribution
# * 4) Adding the new character at the end of the available text
#
# This is the code we use to reweight the original probability distribution coming out of the model, and draw a character index from it (the "sampling function"):

# %%
def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %% [markdown]
# Finally, this is the loop where we repeatedly train and generated text. We start generating text using a range of different temperatures after every epoch. This allows us to see how the generated text evolves as the model starts converging, as well as the impact of temperature in the sampling strategy.

# %%
from zoo.orca.learn.tf2 import Estimator
import random
import sys

batch_size=128
est = Estimator.from_keras(model_creator=build_model,
                           config={},
                           workers_per_node=1,
                           verbose=0)

# %%
output = ""
for epoch in range(1, 60):
    output += "epoch " + str(epoch) + '\n'
    # Fit the model for 1 epoch on the available training data
    stats = est.fit(train_data_creator, 
                    epochs=1,
                    batch_size=batch_size,
                    steps_per_epoch=200278 // batch_size,
                    verbose=0)
    # Select a text seed at random
    start_index = random.randint(0, len(text) - maxlen - 1)
    generated_text = text[start_index: start_index + maxlen]
    output += '--- Generating with seed: "' + str(generated_text) + '"\n'
    model = est.get_model()
    for temperature in [0.2, 0.5, 1.0, 1.2]:
        output += '------ temperature: ' + str(temperature) + '\n'
        output += generated_text

        # We generate 400 characters
        for i in range(400):
            sampled = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(generated_text):
                sampled[0, t, char_indices[char]] = 1.

            preds = model.predict(sampled, verbose=0)[0]
            next_index = sample(preds, temperature)
           
            next_char = chars[next_index]
            generated_text += next_char
            generated_text = generated_text[1:]
            output += next_char
            
        output += '\n'

# %%
print(output)
# Out:
# epoch 1
# --- Generating with seed: "ether of clever gregarious men all representative
# constituti"
# ------ temperature: 0.2
# ether of clever gregarious men all representative
# constituting the same the san the san the goder the same the same the san the same the saint of a present of the same the discourse of the fartion of the same the same the same the same the enemy the same the man so the goder that the same the same the same the philosophers and allotion of the same the saint the san the same the same the same the christian the san the same that the san the san the san the s
# ------ temperature: 0.5
# hristian the san the same that the san the san the san the sariss and resprained allot and the the brought and farture and his ware the same power and the devery and allow degree world formerity and so mare a possible in the say sone of the regards they as a was a man the great we day sensitions, as a saint that the saint of the godned and an is life in the existertially compressions and the depresences and as the grouspance of the lay be one hand himself
# ------ temperature: 1.0
# sences and as the grouspance of the lay be one hand himself in .hum
# it as neversted, a pensous of serlined. but are sworld be everythind and stend of the-idnoun errops one son---with onbseash that so so pants to he sangifician that we-deess made the
# bus strcoted seems--areed frievels with ewery of soperathlest
# sccations
# a lay to
# wat as a ;imparined in the moraless.
#  shenlically e1juy moratity the goded ampostiny al nener sto dore excerstion of whilh
# genisi
# ------ temperature: 1.2
# goded ampostiny al nener sto dore excerstion of whilh
# genisiald fories
# not ratientse,
# and, the pien, an
# abote of
# mode heave allocards, to saintfle the onagient. ip
# unout comed even origesul, serblighd free. the make upself)s as charasicainaling great , the byouted of avoraclificityess is everyts,mpoon,ew
# this agoot, the phision an if presem
# matiesorical ito
# .
#
# exvery contlomd,
# to man, with the :ig(timan be jupty isse--a formelve of what opienod lune. is.
#
#
# epoch 2
# --- Generating with seed: "s recurs.
#
# 71. the sage as astronomer.--so long as thou feel"
# ------ temperature: 0.2
# s recurs.
#
# 71. the sage as astronomer.--so long as thou feel the same of the same the same of the same the same the same the same san to the same to the same the far to the same the same the same to the same and the same the same say the same the same the same the same to the same the same the same the same the same of the same the same saints of the same the same say its and the same and say in the same the same to the same the same the same the same cons
# ------ temperature: 0.5
# he same the same to the same the same the same the same consesse is are propertional deedery and restrutity propossible bring the same man in the giver to a partions and may as its own astimination of the
# same into the conditions and the individual contradering in the spirit of a
# man be all a presently bean for who same life of the same the same carte been something their constate his world and are same with his are without say--for
# same of with the same t
# ------ temperature: 1.0
# e same with his are without say--for
# same of with the same the goites resertion?
# a himself itself of faxies to arroundd. there is no
# ltimes atimest be the himself been finsles as the gavoditadance. the world and the ser, to
# would feelings. itself di injutests the improved. he to this
# opporinedge, in is good aboven rearpons.
# the learng day a m.h, in the
# epsonation sthe were jutg
# us he perhor to great murm, they implets themselves good. necessary and rasted,
# ------ temperature: 1.2
# at murm, they implets themselves good. necessary and rasted, not
# say of wly to
# one good croutuse the :omovely faithulations fears the serves insutarivity es this
# instilblenul
# existandly formgle. of to pa? here with the way good of co portional ttpro philosophictle,
# which, vitum,, voutiations and
# hosely reluciee
# ney misungerciuf werminate himself this may itself of the very arrion. and
# y: even
# nature,  gategof's. itself aftelvessly. but
# it
# a, a but tone c
# epoch 3
# --- Generating with seed: "its limits, the range of man's inner experiences
# hitherto at"
# ------ temperature: 0.2
# its limits, the range of man's inner experiences
# hitherto at the same and the same and the same the same sensity of the same the same the similary and the same as a superfutions of the same the same the same and the same sanger and agree be as a philonopical and are not the same sanger and the same far as the same the same self the state of the same that the same and the same that is all the self the same the similar sane that the same the same all the sam
# ------ temperature: 0.5
# the same the similar sane that the same the same all the same and are need inspired being so this seems of conselvations that the god, and
# the same say have pressuble of the most good for the general comparising and just feelings and the feeling of nature in the same epored had bort and a soul of the can comparising their unifered of accorded in the sinder in the same some period of the fall god say a sensition can in the bead that be remain and satisfacti
# ------ temperature: 1.0
# ay a sensition can in the bead that be remain and satisfactions
# the univer cains seried them or saristicald" at as agains to silful co natural god. that is agethened what free of not asselvation of the negations what
# then so his therating
# of had hn have beinking with a
# reaster dilundering shaditical say
# consider pywer burded are pripol.  ne
# servedd he crosipicied must man taket. it is as was as caused
# called
# feeling been regree, dejudienturp. but to sin: t
# ------ temperature: 1.2
# used
# called
# feeling been regree, dejudienturp. but to sin: the reed good
# that he immore certain sense ippafers of
# that giver a
# paw and manmersityning, have seems of neet: certain all fist inhisminates. this
# animesnes cossly which is  nituul
# fration, infa ancal of least tas and
# were biatt warnincoly, the
# ide
# also perhopical
# because what by had generated afferent basning
# things paren reservar imphitily anr trace from this devolendds againsts in ugratary of p
# epoch 4
# --- Generating with seed: "s indicated that a soul
# feels the nearness of what is worthi"
# ------ temperature: 0.2
# s indicated that a soul
# feels the nearness of what is worthing in the same saint in the same the same the same soul and sanger and the same and self the god and comparising the same the same saint of the same the same saint and and the same the same the same the same the same the same the same the same the same the same individeal and the same man in the same sensition of the same the same the same the same the same the christianity of the same the same th
# ------ temperature: 0.5
# e the same the same the christianity of the same the same that his opinions and the sensition of inter,seed there is to gele in the sacrifice of the greates the exceptions and the same no himself which is himself and serviles of the reason to the moral to his own deem the importance the same the man all the same be as we ware in should the christianity man in the same so desire of the
# same there is not the believed the most the concerning the comparises hi
# ------ temperature: 1.0
# s not the believed the most the concerning the comparises his hight and rigods from it is sunveries. anything readly of caunflessiplesibity happden tried that whichpoman bedinges religion, it has incemination of perhaps by steteris from such appear that its it was the
# sympathy, the believes and if the through the exampy be
# discrumod itself do they are less man atitherent
# that the known, not yet marrist, and shave
# a benise of stands, as so elementic who doe
# ------ temperature: 1.2
# rrist, and shave
# a benise of stands, as so elementic who does natured must destruce of one far doels. norded of their ogyho unundiage aabledane.
#      fatherions of leactely it, he who is things its own naturemful, evil be galnt, which
# does not passe takeb  and mult tiken be heab, therefore venger in such apparanis avided thooughableor at nape mprite his toosuhees the bestness is life, and expetrons of formerly
# sheer are opinile, known, agest ab is once of
# epoch 5
# --- Generating with seed: "man had been a thinking creature, she should
# certainly, as c"
# ------ temperature: 0.2
# man had been a thinking creature, she should
# certainly, as cause and the same the same the same that the same the same the same the same and and the same and allotious and same the same to the same the same to the same that is a perhaps and the same the same the same the same the same the man in the same the same to the same the same to the same the same the same the same the same the same the same the same the same to the same the same to the same and and
# ------ temperature: 0.5
# e the same the same to the same the same to the same and and man should the same and its knowledge. the want the same the demons and an absolute the same the same the partiation had distorted and always between god of the same the same the fathil deserves of a more the wall be not have not been himself hamself so the same in the closely wholly sensition of his strong the same interestive so that in the same than to death and and all in the same sangs he fa
# ------ temperature: 1.0
# n the same than to death and and all in the same sangs he fathorcest comes the importenly, an self doe ban generating the presens. of nature in the
# comparened to
# leads and much, "excloped than to other and man is
# not ditralscome of the sure -actions still ensient laded coper the sin, all serve have abther weakers and he can through infurture wortuht.
# throwgos. a seems shearising of which the being
# fearful more after parts, the strength and for ihes a concl
# ------ temperature: 1.2
#
# fearful more after parts, the strength and for ihes a concludeds upon if without
# same. the
# lavenment intomens.thate regardst.
# in all the mum, in
# t
# xasticily
# attatusmed (indivential anlinesps. themo-printet, superfule, life
# indived ear, ascegion an accelard, the sinfulness-unintae. let us anysmiting to breaks of ulge:
# "not you give, nxpopands have  sanere avided intereot the rese,
# buh bothdness, leads there is sayed incormentible led to know
# any for you re
# epoch 6
# --- Generating with seed: "ruggling with protracted disgust,
# with an ever-reappearing p"
# ------ temperature: 0.2
# ruggling with protracted disgust,
# with an ever-reappearing present and the same the same the same to the same the same and the same the same the same the have the same the same the same to the same the same the same with the same the same the same the same the same since and the same the same the same and all the same expection of the same the same the same the sangtist of the same the same the same the one is all the same the same the same the same the sa
# ------ temperature: 0.5
# me the one is all the same the same the same the same the sare whole are all one was the expected and soluling and suppose and according to the most powerful and ascetion to perhaps not and sangure of the comportating and the ascetion and the self whole speciality and any
# something we interpretation, and as it is play allow the feelings, not he is all exception of the sacrifications and he conselfary in the man strengs and as so fall for the same too, the
# ------ temperature: 1.0
# ary in the man strengs and as so fall for the same too, the spirital in the
# legoar, hawe its nature handers ,hread by yeak that the ourselves the alterded vered by to have do the beine sinlos. naturally bad are superis of
# conicom, and conds he antiquity, as its crould as angersued ane throok
# in the spertic of synfect sates of your simples. are survived its otcersows nor, as to the same convil for belief for home, and not song the ullightening because or it
# ------ temperature: 1.2
# belief for home, and not song the ullightening because or it, theyower
# habouge another or excitive
# nounch venticus some because humself lux-hitsuration, had disanverimy hother--times, one than
# to known--my enlather perceptive, which
# a ideases upon
# the advartoof
# a pares to not im.p ofrhonsly bockriald, a soul peltion of there
# eless, were us
# the suring upon oney we
# will wagne, what saxzing, specimity, existence of slanded soul grething philop uponscy is the
# epoch 7
# --- Generating with seed: "ts "prejudice," grateful to the god, devil,
# sheep, and worm "
# ------ temperature: 0.2
# ts "prejudice," grateful to the god, devil,
# sheep, and worm and the same the contemplated and states the same to the same the contemplations that the same the same the world and and strength of the same the christianity of the same to the be the same the same the same to the greatest and strine and the same the same historic and the same the greatest and strong and states the same the same the same the same the same the same the same the same the same the
# ------ temperature: 0.5
# e the same the same the same the same the same the same the amplay and that which the sense and superfrising in the christians and the are in pain of sympathy is all the same father of the othe greatest had to have the action of self are the sense has the conduct in the well conduct and the exceptions when of his science, and and in the same the same with the self have the philosophical still degree of the restraying how so the conserven who have the great
# ------ temperature: 1.0
# ee of the restraying how so the conserven who have the greatest guims circumstand, foren
# sympathy of interpreters "same matters briwg maftery pleasure make a
# causge of the othe away, has to betthing elicate of shamith action remactid,
# with elehtrous bribls yet the religions that the beal diveted by -sacrifices of to saysiwing regards are highs by goes onn to the kill aways them.
#
#
# a2
#
#
# as these.
# they called sometimanistsium. moned to is agoes, we maves to
# ------ temperature: 1.2
# hey called sometimanistsium. moned to is agoes, we maves to the hother specialting and guars laterces of lwas foundation of his characces. justice, ferief. eth, operatever it has accelated that
# each the the compulsion to importiul almost-funccupseopful ascubed. it
# allounds faquation.
# tires pullingly
# blead geat.
# and preaches in the mevental ten of nathing more
# bano
# poctional seeing feel above a make venglental
# y we the faetimy, gow--weartering emotionnd, an
# epoch 8
# --- Generating with seed: "when it will be once
# and again understood what has actually "
# ------ temperature: 0.2
# when it will be once
# and again understood what has actually be as a pain of the same the same the same the same the same than the same than the same that the same with the sense of the same the same than the same soul and the same the same the same the same soul is a such an indeed the same the same the same the man in the consider and the same than the sense of the same the same the same the same the sight the same the same the same the same of the same t
# ------ temperature: 0.5
#  the sight the same the same the same the same of the same to the same to have a profortes, the sinfulation of an exceptions and be are sadefoly and soul the consequently entor" is to the satisfaction with the stronger the a man has not stronger and the be his man is a good a present this is a perceive all the will one and the standard and however in the soul of been defenters and an a souls an anctuye in the sense of the sense whatever the soul in the exc
# ------ temperature: 1.0
# ctuye in the sense of the sense whatever the soul in the exception of e, as, there and nature and and satter become leading insisces of christian apparactering them to over one certain which or concredemently in hinvertain,
# nod which sanaally philosorus, variedation and seuptaid and on morality so inceres of the soul
# of the mosturesteroly of himself if a
# school, unconditionarnting that free himself, eponsibie of
# pleasure, hare humanity, aoll sare feelings,
# ------ temperature: 1.2
# f, eponsibie of
# pleasure, hare humanity, aoll sare feelings, consideration, but a telling roved arousbends sivn and life, hatt of hcli" make,
#  generation  this down ununderstanded my hiwnorhed themse tastel, rejupition of an i-sumtired-good.,
#
#
# 1not
# may propers, with
# the histanles
# concremely thought, words a selvolve
#
# pierves his
# standake of enrawion cuthing whateken wim. in adbilisturied talled for imes o: truth of general, consor, the satirfust
# a"to know
# epoch 9
# --- Generating with seed: " doing it, so will true science, doing with
# ideas what natur"
# ------ temperature: 0.2
#  doing it, so will true science, doing with
# ideas what nature and the are feel of the same the present and the man in the same the same the same the same and the same the same the same the same the same the same the consideration of the same the same the same the same the more believen the same the sanctice of the same the same and saint and the same the same the same the same the father of the same the same to the present and the same the partial the same
# ------ temperature: 0.5
# me the same to the present and the same the partial the same and astention, we seem the present in the consideration. the gods and since the most sense and not the feeling with the man in care and for and the existence and as he would far as an encesity and the manifestion in the sanctical profound the give of the exacted and an all the comprehinance of the submulters and with the morality. the father and and perhaps believed the propess of himself more in
# ------ temperature: 1.0
# ther and and perhaps believed the propess of himself more intiment to bit deduence himself not thus of with the sugff initably the mame to our
# esweles what
# can believe do more hand unnarred the antiliey that in the conservatly sceens dingropariness. but divers and
# the world at
# uncenes: it is a christianing
# and brievent induste upon this esteems morethed bad emotive advance is christianity of superfice of it), enlopy appeared
# the disposed his deces anyone a
# ------ temperature: 1.2
# fice of it), enlopy appeared
# the disposed his deces anyone and
# latterable of survive of the sitht goopleacte an
# aptite
# perhaps delusiviary, fearlyly more
# tobtheremmad distinguxe relationce, from horable regard to sayes. sipority rationalise mery borg of
# engluscelvar. not to his lade: his plenterfs. indees these green fears,
# exartume therefurdd, hander lreathing than part namely the fall exocation of fundoilfs antarhation cames,
# through so apparat oney divi
# epoch 10
# --- Generating with seed: " of its truth or
# falsehood), just as he suffers from every b"
# ------ temperature: 0.2
#  of its truth or
# falsehood), just as he suffers from every being and the same the man was the same to the same the same the same to the same the conservent and he is a desire to the same to the conseduant the same the assertions and a decisive and the indiving and the same of the consideress and the same the same the same the same and a sensition of the same the same the same the same the same the important and a sensition of the same the learned and the s
# ------ temperature: 0.5
#  important and a sensition of the same the learned and the same and the christianity and the characte it the importance of a man lood and the character and the propes of some harden the one and the same the conduct an influence of the natural all the resist and the everything against the same the christianity of self as he an in the are advance and respect the same society. through the same the destings in its times the result in the world who same in act
# ------ temperature: 1.0
# stings in its times the result in the world who same in act and incated that self-has teachly halis, and if they men
# be ne desconsideed free excerding-sy. they a mind a mark divented man notoos utility and a dhpeareds of recever, strictive between is to science, the
# greatful to the fathing is
# a doon to him ampstrical allood is the needam for this called alreadily frait when certainte it, but the ridsows is in the go sense. they are bedincely origin. as . t
# ------ temperature: 1.2
# idsows is in the go sense. they are bedincely origin. as . this christiane. when
# co muchle which
# illlatic say, the oldespision in that men, hat ad
# certain peenontizamerication. its
# vised, where forth every tooling tree
# nonity and with u imposilities would dection to, an iabse
# of miral of
#
# inteepfored the time, entoo-has does they deemice and rat pertains an aftitations of the
# imperceity than it proomis apphiloosically bithment
# celacretroo. what is
# thisgspe
# epoch 11
# --- Generating with seed: "assume a voluntary,
# ruling, free will, and in the former nec"
# ------ temperature: 0.2
# assume a voluntary,
# ruling, free will, and in the former necessary that the same the same of the same the present and in the same the same the same the same the same the same the same the same the same the same the same supersomed and the present with the same the same the same the same the same the same of sandoment and an acts the same the same the propess and the soul in the same the propess and accompance in the same the same and the expense of the sam
# ------ temperature: 0.5
# d accompance in the same the same and the expense of the same the same of the conscience of all gaves the particular men because and if the same the proves of self anything deception and the complate the feeling and the look and all other points of all opposite be solul to real called able the christianity of all the conscience and the more senses and for the same of an acts that the self perceived and deception, the same the instance. if it seems the part
# ------ temperature: 1.0
# d and deception, the same the instance. if it seems the part of lates, wers man patidere regile with the excised insolval than yet
# ventreness and smother of the ensensible. its
# wills of the. eyes and because
# emblance of dance. not at one is not inceriousness and stretelists and reality
# from reitime an ecconding the well peronair of
# sympathy the saintiness vicsical, defectul this sympathy were suspupue his scegrismos the develops for the lose in death some
# ------ temperature: 1.2
# upue his scegrismos the develops for the lose in death some truth goodg. why gretter relugicies
# also irrolofline of merely from deless the submult wertallot: as leartal
# affects more daded chpoa,
# althiums been sacritaravroly 'mattering influence of
# the through whinh, is pullal knowledge,, windedly  he
# rattennurs anoterles. if bort omexparedment necessmection, high paoled and visunce. here belience of seems to himself belief
# they af its upon its opinions its
# epoch 12
# --- Generating with seed: " for which, owing to good reasons, it is used as an antidote"
# ------ temperature: 0.2
#  for which, owing to good reasons, it is used as an antidoted and the look of the same the comprehensible the same the same the same the man and strong and so that the expearable and strong and such a comprehensible of the same the bad to say the same the same the desire and the same the same the same the same the same the propertion of the more sacrifical and an absolutely experience of the conditional instinct of the conditional same the man was a profou
# ------ temperature: 0.5
# tional instinct of the conditional same the man was a profound to say an evil conduct and in the one is an all superstity and individual themselves and the manifests the brain to the delightful men who perceive of the sancticism in the man who
# perhaps to deemed and he would be condition of the christianity upon the looks and and not to the result and this present strong and with a sort of christianity the profound the sensible propertions of rational sanct
# ------ temperature: 1.0
# nity the profound the sensible propertions of rational sanctity as there
# app of neare, therewitherment death,
# himself of life modes of such grow: in the puallings how the in
# not is bring uncaragened of no have been
# artist penpletion and have decupiladeness and profound with any souls that
# excernal blarglete times of sagpenting at an haid to which slaved to promited not ho harb former can large,
# a ney
# are
# a modesty upon well opinions and stoost
# for solitude
# ------ temperature: 1.2
# ney
# are
# a modesty upon well opinions and stoost
# for solitude of thei.
# this synthesis is compulserble so
# imable upon dipane as dispossible
# xcondorly, are notsile healt. opmotist; not dulotic wen to ponsen token is exparations in hists on nature.
# trush then purior peopress of absolusines of become of imagnting cielties sweek,ness when by kinder for
# increasing
# christianity insirhing
# gradeful very lit well
# is pretencuor--froh? at o nature heaviering dogmanx wh
# epoch 13
# --- Generating with seed: "eliefs lie sensations of pleasure or pain in relation
# to the"
# ------ temperature: 0.2
# eliefs lie sensations of pleasure or pain in relation
# to the same and in the same the same to the same the same and any pain and all soul is a stronger and saint and so desire and in the conscience and all the same the desire that the same the same the same the same and saint and the same to the same the same saint and the same and sense and the same that it is all the same saint and strong and saint and an exceptions and a complete and all the same and so
# ------ temperature: 0.5
# int and an exceptions and a complete and all the same and some conserver saint and attained that in the are an able to the greates and that the warts of the same comprehensible and in the same partialt so called beartis and himself that the such as the sarth. the more an account and of all the same deduce of the more than the same later and subjection of same and all soul is all situral conceptions and the first sense of being thought, but the souls all th
# ------ temperature: 1.0
# s and the first sense of being thought, but the souls all the development to all others, no littoness is his the imagination and way inexultce in conjuited to woman
# to wellity and mark of the learned that
# ifpted to domined, an
# are the borriht more philosophy sensitiel whole
# complete of
# faronatic
# excitication, which ashaved because it withvented wagner of understand themxress, it. an the gratusodational ratyger love so, and if "withortiness of the longing o
# ------ temperature: 1.2
# ional ratyger love so, and if "withortiness of the longing organism reuigations and dose of the high this been
# free spiritual suspectd and measured pides influence in"cine than conscised beyond
# world new
# docah histocked, sympathy inow hodisquing falling fundomancal seating, always it whet remain.
# a situral, so countful superterments
# indigin whole spirit in thoress. peaco. hiserss; yet voss whose inventured to pyination a, confludespsmers cixes,. effects.
# t
# epoch 14
# --- Generating with seed: " also was unsuccessful in his
# efforts; and whoever has thoro"
# ------ temperature: 0.2
#  also was unsuccessful in his
# efforts; and whoever has thoroughly and sanctice that the same the morality and the same the same the same believed and the same believes and the same the same the same and satisfaction that which the same the same and the same and strong and the same the same the same the same the same the same the same and the same and all the same and the same the states of the same the same and all the same the same and the same that the s
# ------ temperature: 0.5
# e the same and all the same the same and the same that the strong to the same and soul of his work are already one have himself because and a provedering of comparating first the first sure hargges and the interrous alled bad and the complice of the helple of the present himself and the deeked the most knowledge of his acts of man speaked that the good of sanlism concerning that which as so sensition
# that is always be strong and power and the same with the
# ------ temperature: 1.0
# ion
# that is always be strong and power and the same with the underduce learnen in tandmans. all things "come which is
# through regarde exactagion growth philosophers, man willing desinsmical
# sacrifice, but certainal origing of heind existence, which he pitked and an away
# in the econces.
#
# ind upon
# the exception and for contred to establint inhertarnate one hat its falsifice it be ascable,
# to .abverse who plays never feeling of forming a, the
# guise of has man
# ------ temperature: 1.2
# e who plays never feeling of forming a, the
# guise of has man
# andactionly in
# platoner of lated blind, that they will far
# astary very beinifiness of bilotderly basia sagredness. and as once
# of
# god. nontains has essencess always--this, wispors--actually
# pension that in
#
# .fwilied
# that a pet each himp, must from hes langhmatic, sorts cortinevoly in
# suffering
# mechop just allow religion, so pointingish worned.
# forment oft toous oecaless. hac,s love
# oweer science
# epoch 15
# --- Generating with seed: "ore us out
# of the grave of their primitive antiquity! is one"
# ------ temperature: 0.2
# ore us out
# of the grave of their primitive antiquity! is one is as a sense of the same the same and sanctity of the same and satisfaction the same the same the same and so that is all the same the same the same and some with the experience of the expedience of the same the same the same and attained as a super in the same the same the same and sanctive of the are some the same and some sintiness of the same the same of the same the same that in the same th
# ------ temperature: 0.5
# f the same the same of the same the same that in the same the present science that the
# destructible that in the restrament of the conscience and home of his power and comparison--as the same the expeded the more anyone that in the restrains the power the delight and so much as the reverse and desire that the comparison the truth and the disconal life we are sind and pared with their demons and same in the former the
# power. of the desire that is a higher fa
# ------ temperature: 1.0
# e in the former the
# power. of the desire that is a higher fathiu but know too, in his own betweent because,
# in
# the regient altrouting, all burtly perhaps wade.
# the restracics as a tructed
# in
# the will been suffce. in
# the resisus away be the sain refineing disenls
# conside
# to look is adreath laging in its upenald
# juhtice in pention, the included with, as some incabutiants that in the impupplies,
# in the distin
# than delusiate of sagkeng, as he have shook. he ca
# ------ temperature: 1.2
# he distin
# than delusiate of sagkeng, as he have shook. he case and ngorements of enverse in immeat, at all ruther
# father or without taken brattal, an averaone, all grage.
#
# arture and it, because the first a varierly usepols
# pitked of celtarogial,
# bod adounest agree ivelt of penitaved,
# edurarity.=--sone bactable perceive asure growt
# impoltle psychologion, predection are deeds the made he feelings,
# in the
# yet himself pechis. if
# their
# subcleice byeth
# rhlie.
# t
# epoch 16
# --- Generating with seed: "s] moved,[11] and we never get out of this circle, because t"
# ------ temperature: 0.2
# s] moved,[11] and we never get out of this circle, because the same the same the same the same the same the same the same than the same to the same and so that the same to the same and the same the same that the same to the same to the same and such a sense of the same the same form of the same in the same the same the same than the same the present sintings of conscience of the same to the same and sense of the same and the most sense of the same the same
# ------ temperature: 0.5
# nd sense of the same and the most sense of the same the same with good against this disindeen of his present and in the
# same man destance, as the conduct. the soul in the same and fear soul is in the account and compression of the own acts in the demands it is to be an experience in
# the greated of the same form of the restraint and the exceptions who sacrification in the philosophers the restracies of interpretation and the teaches. the same feelings and a
# ------ temperature: 1.0
# s of interpretation and the teaches. the same feelings and as the more love the fined to will painforications
# are dull intenpulances.
#
#
# 135 because danthing sunderew? but the germaries, perhaps that cause of life for
# a potent develipations: thus ever does not free which he maytomeds of deep essenticies and interpretations;
# for very offerers of compares a life with the been the fine can do not ascestiveps to the capanity, to pall and much case in littonan
# ------ temperature: 1.2
# cestiveps to the capanity, to pall and much case in littonant him we nations, ganitions, how clove if clow: and a pervertably, they good,abit earted
# eyes. however
# cannot lumit circimition lality, of sarts, diint faculute of ruh caan another. is dengerousness which
# thatiss his betwomay should life are one
# uponse all involutns themwaring, but it is always, and this fulthers secthivates youablens of the resecvuity dorty he dehence is look
# xartly it to head h
# epoch 17
# --- Generating with seed: " whosoever has experienced any of the consequences
# of such d"
# ------ temperature: 0.2
#  whosoever has experienced any of the consequences
# of such deserved the same the same the same to have a states the same to the same the same the same the same them and the same the same the same the same to the self expendence of the sense of the same self being and the same the present solection of the same the same to the same saint and so the same to the consider the same to the sense of the same to the same the same the same to the same the same to th
# ------ temperature: 0.5
# ame to the same the same the same to the same the same to the act has not an ideat in the bad are so will consider still believe with the same to which the passions of sannotver with the does not being standard have been
# feelings of the religion of the same of the marbid of the one restrarily to one has not the same the sensitions and more an exception of the fatherfer, not to
# sanctity and the christianity and the same and the the most capacity been the in
# ------ temperature: 1.0
# istianity and the same and the the most capacity been the insight ;ith can deigh these which or he will matters; a crude mere the sscainted an above the balantered a god, where -appearationpain-grateful and brbigined good with
# feeling with the good
# very time peace of
# one's benelvidly betutely hand perhaps present things: evens to good appeighters. awaverness in society is general with the greated be
# grext regards and attribard
# the same indeed to disinor to
# ------ temperature: 1.2
# be
# grext regards and attribard
# the same indeed to disinor to manife of trushe
# inctrpative will one are gloo-pressagion in view but anbiatic and ever rether in the
# who would not
# wat wish in this stokeven mood of
# to the taste, through it grow. why idea our some "re each whi, fantoponipater.
#
#  hy knowledge, invo, as all sort of othersulevted almost
# wrong of philosophici
# ruling can bction y in yeapsitie of
# the sithers, has not distrutes. a high ulded. an rates
# epoch 18
# --- Generating with seed: "on gives inducement and
# opportunity to some of the subjects "
# ------ temperature: 0.2
# on gives inducement and
# opportunity to some of the subjects and the same the same the same the same the same and the distorred and in the same the same the same of the discourse of the same the same the same conduct to the same the same the same the same because it is always an acts and the same the same the same to himself and allow the same the greated an admirate the comparation of the same with the same the same of the present and an acts and all the s
# ------ temperature: 0.5
# h the same the same of the present and an acts and all the soul has been feelings of the false of the love and the interpretation to the same with the present seems the save strong and because self and the greated he called and the same same good and saints and at all soul has false of all superfror not it from a self arrange of the evil in free howselers and individual that the calculation of the same sacrifices harning the individual in his time upon the
# ------ temperature: 1.0
#  same sacrifices harning the individual in his time upon the
# home, and christianity fall of the science up slarks upon
# peath maltarities.
# forezantary acts be-fore in the a philochicardness and
# the tram calls there is connects no present:
# we deserversy than to consciencal origin that have a great freg self soul, a most. the man than so have in higher be inopined he
# interabe that yet when i phymcaling religions but that his anyone
# tradition of all resocishe
# ------ temperature: 1.2
# ng religions but that his anyone
# tradition of all resocishe gentine
# bothen that neversuve as wherefort buch former oyem, hedel placedary, a
# ppeion. what, impreasoninaly
# salvation. carribile: if thyeom of redlaies
# loodomo-ify that, if by the hones, will
# olvepigl good puile
# the bekne upon
# afhirs that is because i louts nature many bounce, hence prayerertine there
# should sense in with
# indiegene created  or adested "sirs sotile. thiss number, allequoist men i
# epoch 19
# --- Generating with seed: "t that it comes too
# late and not at the right time; for, as "
# ------ temperature: 0.2
# t that it comes too
# late and not at the right time; for, as a more and the same of the contempt of the same with the same and the same the same and all the same the same the same and all this seems to an able to the same and the contempt of the same and the same the contempt to the same with the same and the same the same and in the same the same and the same the same of the same the same the same the same the same the same the same the same the same the s
# ------ temperature: 0.5
#  the same the same the same the same the same the same the sensition man is the substiny that the sacrifice in the
# are something in the sanbleness of in the life and with the warly and one may be regarded as the same with life and discorrive and action of the latter the same and all the same his own feeling in the natural very restrated the same way that he sacrifice upon
# the same the same and the present even in the interpretation of the religions do not
# ------ temperature: 1.0
#  present even in the interpretation of the religions do not rativels view, and knowledgely initase origin to this seems to the enteriations which sunder sweecimn and interpretible that their louthly insaived dostrius of all a missides of circtained, he are want contempt and make been they have exercosition : all:
# the sforturated himself ever
# lie these domined earlier result in utilece to possibility doophy to they hope away
# this exacted that will poten him
# ------ temperature: 1.2
# ty doophy to they hope away
# this exacted that will poten himself better, by henquits) is ant the lue profound
# the demoks-forence, a thin sacrificing of humble good than belong opposite. in
# the time shart it
# takes, poor dreads the first expoolenations, are soccetic to manger, even h! ordyywhand matter and waable gave
# through
# all peeiliesmenness as as
# are made so, that is to) pumpte is
# trositing is at pitians imagination, are we are once incatefooe
# clwares a
# epoch 20
# --- Generating with seed: " equal footing: the
# powerful man in turn invades the domain "
# ------ temperature: 0.2
#  equal footing: the
# powerful man in turn invades the domain of the exceptions and the same to the same the conscied the same the same the same the same the same the contempt to the same the same to the same to the same the same to the same the same the same the conscience of the exceptions and the same the same the promisence of the same the same the same the same the same the same the same the same the religions and all the same the same the same to the s
# ------ temperature: 0.5
# me the religions and all the same the same the same to the same to have act of the consciedon of influence of potene and all act some are to whole to say and the same that in perceived the concluded to unnaling and the god and to have so that in the same the destruction. the individual double the sensition, and the same the greated and the christianity of the ethic of god and strong and the religions and all the same for
# for
# their
# consideration and all sol
# ------ temperature: 1.0
# ons and all the same for
# for
# their
# consideration and all sole of saintorism in the
# tearing, to things have not regarded again, grow, as well one earles for
# lealted a case, arrind in the
# new over
# him. they ayoris would not be gained, but they was indeed at easy a pronomptiratenessing without
# culthers of sinctrical agidegness wholled and strumce atraim. the eswelf with man "singlals as to datiation.
#
#  havely impoftitial and by
# the possibley mother fear of gr
# ------ temperature: 1.2
#
#
#  havely impoftitial and by
# the possibley mother fear of grateful, realifies in order to humand edyer, for the unlecorto apar its in the up than, he
# hone which he reality
# seterlishes and not
# truey
# ever truth.
#
#
#
# 13
#
# =be things
# the mid rode,
# inspire aconk
# mhey of christion schied. slear and ? that whom foothlep mysagers, inalitymeanness. and their selfitacheous, pedidical motring
# to ripios all utility is self, alone, as if stead to
# be wi solithazed that  k
# epoch 21
# --- Generating with seed: "and in the presence of nature as a
# helpless slave, he is not"
# ------ temperature: 0.2
# and in the presence of nature as a
# helpless slave, he is not and the same to the same the same the same the same the same the same the same case of the same the same the same the same the same to the same to the exceptions of the look and the same the same the same the same to the same the same the same to the same to the same to the same the present superficial the same the desire to the same to the same the same the same to the same as a soul in the same
# ------ temperature: 0.5
# the same the same the same to the same as a soul in the same to him and feelings, the same the same of a soul. at the same called because of indeed they are not
# cause in the excite the
# power as a selfing to the restrical outions with in the according to the rendered the far able to consider of the double mothers and in the consider
# men to say that he will to a storings of reality of the look as a profound that the greatest enterioring sympathy the particul
# ------ temperature: 1.0
# profound that the greatest enterioring sympathy the particularly to bedictor to
# siffered and that as
# their always why pleast an) it.
#
#
# 12s or lett at am as the greated invention praise for
# and be the last power and
# asire a prepseder.
#
#
# 133
#
# the ladure choule it is a god, recluereness., at the have all of the existence of accordive wholly
# thinker unupraving blangesr would be
# the various
# to the conflueh need or if the strle evis, one
# of a long naive of the i
# ------ temperature: 1.2
# lueh need or if the strle evis, one
# of a long naive of the immortatonchinations woed us to plans of he typture beyond indeportble nermutes of thum through the sort severly former, delights about the generation thoure, the same jsolve ingraous. if it is value power scrudute. the
# termary
# pretfulnessmencess ,aide,
# and a eather inningiving his when it normeg? yess auguling most puenegeremons, teachus humilo: ceastratidn him.--this.
#
#
# 144
#
#
#
# aut and but the s
# g
# epoch 22
# --- Generating with seed: "alled
# evil, the tolerant, unassuming, self-adapting, self-eq"
# ------ temperature: 0.2
# alled
# evil, the tolerant, unassuming, self-adapting, self-equally and in the same and the same and so that is the same and the same to the same and self same and the same and in the same and all the same and the same to the same and the same and the same to the same and the same to the same and according to the same and the same and the same to the same to the same and the same to the same to the expression to the same and the same to a propession of sanft
# ------ temperature: 0.5
# expression to the same and the same to a propession of sanftical men with the present some that for the origin of life and sun the are not to the dose of influence of the expression that is such as a men who can from the sense of man is restouts as he destruction of expecter sundered themselves whill to conjuction of the man is not that is to the christianity of the such one is that the sundered the suffering in the same to its intellect which to say the f
# ------ temperature: 1.0
# he suffering in the same to its intellect which to say the false influent reself, with every valuations
# is thetherriffer syrtom it is evidence and the hraces himself to lo free justification of strongethey, has remain are act frounce-spirch, to discolority
# to nature and plement in the all sensition or for ever sole of our limitation after a life are way, as hate because seecher -of the greatnesse of an"ides in men in the
# general right to pleasure and the s
# ------ temperature: 1.2
# of an"ides in men in the
# general right to pleasure and the serior man may grow. onle, and
# to the consider their
# god, plato one, all stious of since, as of him first anbiliness of mere muture) doble go,," if whatever ashertt would sating evereviols
# were of intelled to
# subjection too, is externallerly althreedings when to an evolved to vieweness of rassions which who reveilelkness and civilize allucety, suhe, siunced ashumed until from the suffece astatimat
# epoch 23
# --- Generating with seed: " worst sense barbarous, asiatic, vulgar, un-greek.
#
#
# 115
#
# =b"
# ------ temperature: 0.2
#  worst sense barbarous, asiatic, vulgar, un-greek.
#
#
# 115
#
# =being to the same to the same to the same to the same to the same to the same to the same to the sanholy that the same to the same to the same to the greates to the same to the same to the same to the same to the same to the same to the same to the same to say, and the same to the same that the same to the same to the same and the same to the same to the same to the same to the same to the same to
# ------ temperature: 0.5
# the same to the same to the same to the same to the same to the life and the first the conscience and believed to be read with a religion the father of his schumable souls and as make all the far as a feeling that it is not the inspire he present of some thing of the power of personal great cases by delights of deceived and a man was anyoknown of the simple much was so that a deceive which that who have hitherto that the problemed which on the same
# to him
# ------ temperature: 1.0
# o have hitherto that the problemed which on the same
# to him that man a doumngen these sighty of perfecte it by the will to decessived viden
# france to copinar being upon themseleddingness admirates a scancitable prepsic in atite of the fearful, as he indigntliness affarms uncloos othersme and the precourses of this, in
# his then eyes.
#
#
# 144
#
# prhilly natural galescy gaver communtical
# siture of in the powerful speaksuve rercule wholl caves wengereness he fearf
# ------ temperature: 1.2
#  powerful speaksuve rercule wholl caves wengereness he fearfly searing having knowledge. it is
# quite
# than thinking absolutely,
# that as
# means to be easiect it. that i reale, of hence not
# bring pyrises. which sacrificiates of ascetit with a se, their duman cerropsile.
# ypprinaure an.
# -accurnes by drey,"
# for at your "gremralities--who more tidesteugance that the dosie his own wild, to tradagation to
# venturuiut. on: an insight home-both as pares tompulse that t
# epoch 24
# --- Generating with seed: "on will learn to be
# somewhat on his guard against german mus"
# ------ temperature: 0.2
# on will learn to be
# somewhat on his guard against german must be better world and the same to the same to the same to the same to the contempt of the same to the same to delight and the same to the same the same to the propession of the same to the same to the same to the most conscience of the same to the same to the same to the same to the same to the same to the same to the same to the same to the same to the same to the same to the same to himself and
# ------ temperature: 0.5
# the same to the same to the same to the same to himself and the same man they are sanding the presented the presented of whole the subjection and a man as after singline with the are a man provoess of sanfter habithers with the the indifferent men by the seeming brusteles are so that they are in the present conscience of the god that in the great, the more said the same to him and a man later to the seeming and man states the man is the poten the perceive
# ------ temperature: 1.0
# ...
# ------ temperature: 0.5
# e result and the same the same deceived and the same and the father in the excearism, and comprehensiveness of morality.=--though the stally fearful than the same and the existence of the present men and forms and saints the ware such a powerful and that is to be last and concerning the complication and so impossiblity for the indians of
# accompand a religions will be read delights of a father has all their adage to his are not and should not painibed the e
# ------ temperature: 1.0
# all their adage to his are not and should not painibed the eternal time and dochience of relision and notar, if in fakier crongiterly
# heart and the judged hupenscauul homour sade is that carripite of their eurto so cally upon the
# significad
# man is action is repide with personally made as in the booditiation of
# fearfuling the potent, was bring himself, but a refuled free
# highouror
# than deats centring writered) charming much the
# such the greatal but the grea
# ------ temperature: 1.2
# ng writered) charming much the
# such the greatal but the greaterated whatever extrable afford go deceptor, of lidlib"--which the learnes owin
# history sensation and greatness, christianity arinered vicus, evil most except mak, begins up down expectences. and apabilities) been because how masterfflul cheritfuit when so tor sceaits prute.
# by fasting spirit.
# merran. it updolation) but he never quarreed,
# from things of other suffer.
# is being caje, amite
# of his
# c
# epoch 53
# --- Generating with seed: "frightful martyrdom of
# enduring dishonor in the presence of "
# ------ temperature: 0.2
# frightful martyrdom of
# enduring dishonor in the presence of the same former and so that the same and the same and the same and already strength and the same false of the same and always an involved and in the same and the same and the existence of the same and the same and the same to the man to the same and a sort of a cruelty and there is a man not be assume
# to say that the same and the same to the same and the same and the contempt of the same and the s
# ------ temperature: 0.5
# the same and the same and the contempt of the same and the same travelhism is a soul to be an existence of the false of the greatest serience, as if the being at may be be can be sense of the tradition of the general would had to be suspect responsibility themselves as a finer themselves to person is a consequent soul a man is the chaince in the antiquity that an atterhier with and the degree. a satisfaction of the single and that the man regratic of disti
# ------ temperature: 1.0
# atisfaction of the single and that the man regratic of distinguatix is lavors--no, oux there  the sanctifives their world and in
# one loug he taken well? not the historianch only human free man well otherse, one call
# anoo us a resulted had to some baught that to vigld much circumsd causes
# be different poothes a
# looks of it. without indirinfually and the suhed, hitherto
# without afford insight himself, in deluce and it oseon what is, antiquitus out who are on
# ------ temperature: 1.2
# f, in deluce and it oseon what is, antiquitus out who are only entimativena bad actsery
# himself
# and no feeliant.
# in des it. a
# lex, sacrificity of to anyly peoples became by which europe telitary invinciats with
# except pain, heself in the same consenssing, volientian to love verw? whatpil by barneister in the phisions. proucble depend are termind. philosophically peoples occasion sympathiousne callsd
# it is about but a te rate at luage nothing carly but lang
# epoch 54
# --- Generating with seed: " is capable of fixing his observation upon
# exceptional cases"
# ------ temperature: 0.2
#  is capable of fixing his observation upon
# exceptional cases, and in the same conduct and in the same fact to the same and so impulse of the same feelings and the same to the same will be artistic the same and the same to the same and the same and allowed to the contemplated to the same and delights and the same faith in the same fact to the same and sense of the same faith in the same to the same to the same act with the same and true, and the same and th
# ------ temperature: 0.5
#  to the same act with the same and true, and the same and the former strong and light and man in the same from the delights allooous and interrops of consistence, and such a contenters, and if the parations of his sympathy of the fame and can in the same same and man can do so the stoosily experienced of cause in the progress of taken which as a fer in every sort of the latter work and from himself with the mended without pleasure.
# the same wortd and of pa
# ------ temperature: 1.0
# f with the mended without pleasure.
# the same wortd and of painful, "the most bentrivic
# view renoptomen the basis of conduct. but not circumscreponsment as an ahself with and look are maoned suppossion.
#
# the obvisor and bring canevercjuss domen
# discrefer. the love
# that preach
# interite
# sink cultures--for the sonning more progress. for in all personal another. good, whewered that it is a cruding strengthes science and his tokesing with which the
# earth) of rat
# ------ temperature: 1.2
# ngthes science and his tokesing with which the
# earth) of rating of hesing judgment accfoness.
# pentomer
# paris attain the romantic. to danger
# of cunned like taught to the lack of the
# former naturally grown experience, neverthelesson in shortny of we dogmoral. for withoul onee convant men, and ratily reckonatic
# cyrilew: it is, to say, inkienm arprons act and understrore tolity may daring
# religions, the ingerually, and he may act brever evil to general and dic
# epoch 55
# --- Generating with seed: "nocence of admiration: it is possessed by him to whom
# it has"
# ------ temperature: 0.2
# nocence of admiration: it is possessed by him to whom
# it has not that the same and consistence of anything the same and the same and the same the same and the same and the greatest some man the same to a man is all the soul and the same and the same and acts and the same and the same the contradished and the same and the same and the latter the sanhing and self so that the same and the same and the being and the greatest men and the same as a sort of the s
# ------ temperature: 0.5
# e being and the greatest men and the same as a sort of the same some thing are evil one has a man will be good of the commands and such the evidence of
# the presentiment and the exceptional philosophers regarded and his "presentiment of standard is not and such a false and the promises betured that the interest and not interpretation, which is that with religion of everything works be encesion of the man is now all the same fellow well as the
# natural sacrif
# ------ temperature: 1.0
# he man is now all the same fellow well as the
# natural sacrificing
# noble for unredulus or a fapting betwiness
# hokin to exampless
# a
# mutual domain of the thing upon econamit of far frigial religious will evire a man himself for power something recertainty, and really soet the tradition, comparison in all self the greate of himself to
# a product of an heart, or are how situpard believe conduct is simply feelip only not unsameness of the certain the dowary child
# ------ temperature: 1.2
# y feelip only not unsameness of the certain the dowary child necessary,
# has forget and dutaking upon life would be injury itself for in suls sphaning imposed to ways, and as a
# eather, forshucity and being when
# the
# will to germans. among fool logically she strains of its
# approlinaryes and insevoedses,
# gloosy,
# poly to the
# more wipues, along give for to, wi vuse perhaps domat, and not pleasen with by theceed culture let new, cosius shumpllo-coverate thereby n
# epoch 56
# --- Generating with seed: "e rareness and the difficulty
# in the deliverance of such a p"
# ------ temperature: 0.2
# e rareness and the difficulty
# in the deliverance of such a powerful and the same consideration of the belief in the same and so that the same acts and can be as the present and consider the same the same the same strong and so impression of the consequently because the same will be life in the same still consequently and the states the belief in the same the strict and the same the same the same concerning the same and the present and so that the same from
# ------ temperature: 0.5
# oncerning the same and the present and so that the same from
# the religion in the same religious fellow the satisfaction. the religious sort of the greatest men in the case of an honoral self be able to an include and more feeling to
# the sabiflly doman as a deceived that the individual the sanctiness of the latter, it is called the can in the same false of being formerlier man with the distare in the state of the same strong--and mans of mankind and without
# ------ temperature: 1.0
# he state of the same strong--and mans of mankind and without the sentiment to
# perquilots the
# proced to liftin to
# senality.
#
#
# 101
#
#
# =then are, they bades of the expensely importany and sinity the tradited to-ineralsing envy bperys. if he wake one greatness and emplan relations. he rest of younhtered and ceptical science by new and its perties by a so: teek: itself of churnified that to a contorting and very evil science. th much consent and relations of cre
# ------ temperature: 1.2
#  and very evil science. th much consent and relations of cregaring proved medity:   i nurite out in it
# latter
# abong.
#
#
# 135
#
# 1
#
#
#
#
# =customle gratational puach would ins cruf apot"
# the answes, at is under
# cleemforent and
# more
# were overmeatime
# exceptions, it repraiing
# as these slosk love with his feeding delughake thjowuch explanation--circumsced from the sliparing. it is any masters: they apotes diash bird mounte are, atgraliness;
# theority in harothence, in
# epoch 57
# --- Generating with seed: " solidified,
# granite-like foundation of ignorance could know"
# ------ temperature: 0.2
#  solidified,
# granite-like foundation of ignorance could knowledge with the same and the same and the same and the same and the same and the same the same and the same and the same and the same as a sort of satisfaction of the consensus and sensitive such a sort of the same and the same and the same and the same and compulsive in the same and the greatest the same the same and the same and the same and any strong and so makes the same and the same to the sa
# ------ temperature: 0.5
#  and any strong and so makes the same and the same to the same the problem that in a consent and correspondication of nature to which they be son to law and it is fortunately in any satisfaction in the same are being and againcerism itself by the subject of the interpretation in the
# greatest the responsibility in the case and the same to the master for the subjection and the distorred by a general one has former they are put of the subject of his to be sta
# ------ temperature: 1.0
#  one has former they are put of the subject of his to be stats dore and speciess were himself when they wengure reflectness prohans of irreparts and comes these
# christian pain fortune man to christianity nature, not still point which a christianity partially being anweaved and acier--delights. the thesism vict, the asceticism byrtic reward and tradnization through
# reluctive these moralities whether
# excessibility and christianity upon dose agreeable in a la
# ------ temperature: 1.2
# r
# excessibility and christianity upon dose agreeable in a latest action
# europe saj.sicikeness would imagq(ionaling alown
# onitee, got pener alsorly but to nature. once know
# thought and
# cavereance. "the
# discogntersmec toward.
# truited perceived collfuce that sonoging amisses videin wise witnwaine graced
# secluminate become hewness words?--but if one's would furious of -
# as searm yes invance; in
# respempedings
# the justicing expordences acted th ungerments deciev
# epoch 58
# --- Generating with seed: " long, it now
# proposes in its wantonness and indiscretion to"
# ------ temperature: 0.2
#  long, it now
# proposes in its wantonness and indiscretion to the same and the sublimate the same and the same are the same the same for the same and the same the same the same the same the same and the same the same are the same as a sort of sand, and the same and all the same the same and the same and the same the same and the same the same the same from the same and the same as a strife in the same and the same from the same and all the sublimate the for
# ------ temperature: 0.5
# ame and the same from the same and all the sublimate the former, in new and is a property.
# and the sancting of the same and in order to real to say, but the most self some still be fellow the latter will be the higher had a man all the should be so called the sin and in case the sentiment that the same tastes in men and the demands and never a man will death the things of the same former in the
# same the virtue in the world formutuate of an exception of hei
# ------ temperature: 1.0
# me the virtue in the world formutuate of an exception of hein,
# recfemciss. this species to the potessies shotent dangerous death and other which is finally mand-smillesfolds wortd in
# which he canever happiness leke and its proces he consensus jesuit has not as so
# canhe. that he seacative out of the caaning and its eumoting
# so men of an end of her do not being one regard to says matters: it person oneral surpown by his will no cause that an ident as the ear
# ------ temperature: 1.2
# oneral surpown by his will no cause that an ident as the ear to tenulness of contradievity..[
# they out believes with circles, this is ever sensual human wence, of an important segric and that" is scourged. peace and
# loseacy man.
# the idea look, rule bitim that his made of
# itself--has its pirch and reference would have rashion of
# discourse to the whole
# ascetication, when type and of hid above all lated lovely good, in
# this gajegerfur, exposedsing
# but
# comes a
# epoch 59
# --- Generating with seed: "iefly because they must prevail, or else
# run the terrible da"
# ------ temperature: 0.2
# iefly because they must prevail, or else
# run the terrible daring and the same and the same and so that the same and a man will be consensual to be as the same and the comprehensive soul is a soul of the same the same and in the same the same and in the same the same and the same and the same and the same and all the same and the same and in the same and so that the same and all the same the same and the same and can be as the same the same as a soul is the
# ------ temperature: 0.5
# nd the same and can be as the same the same as a soul is the same the significance of self be not the desire to easily his desire and compulsion and desires and in the will to be deception of the exceptions in the present man in the most acts of the same as subjection of himself and the deeper sin and evil one not one of the same and means of the dangerous to man in the love the facts the pain, the truth in the higher worker and the same from the most incl
# ------ temperature: 1.0
# e truth in the higher worker and the same from the most incline to
# stupimising sympathy how siide is no, the
# excite brought the perception, platise
# that pekinital exmited. laterarie for the decratic sensation
# and absovmy religious about phenomenan disemnan, a determine state of metaphysical sense in the
# present moral
# stre
# own and a slibptce are sonrate, limitice chains to the fact to us, hampund, acts and true-coust the last
# perrensical christian dutge exp
# ------ temperature: 1.2
# acts and true-coust the last
# perrensical christian dutge expresss of chysily man of superstionize of a
# gider.
# they
# douth love to able of upon the  a sense, necessary, good such a wure these upon for pourses that deitael would naturally brought to enausal,
# asceptnists any sphanit, in immediater, my mind of misthe alrquibe the other worshd should asking the
# hading, only existeness in
# nalusious "homity). here
# as the price, with his superluin,
# has upon the him

# %% [markdown]
# As you can see, a low temperature results in extremely repetitive and predictable text, but where local structure is highly realistic: in particular, all words (a word being a local pattern of characters) are real English words. With higher temperatures, the generated text becomes more interesting, surprising, even creative; it may sometimes invent completely new words that sound somewhat plausible (such as "correspondication" or "thesism"). With a high temperature, the local structure starts breaking down and most words look like semi-random strings of characters. Without a doubt, here 0.5 is the most interesting temperature for text generation in this specific setup. Always experiment with multiple sampling strategies! A clever balance between learned structure and randomness is what makes generation interesting.
#
# Note that by training a bigger model, longer, on more data, you can achieve generated samples that will look much more coherent and realistic than ours. But of course, don't expect to ever generate any meaningful text, other than by random chance: all we are doing is sampling data from a statistical model of which characters come after which characters. Language is a communication channel, and there is a distinction between what communications are about, and the statistical structure of the messages in which communications are encoded. To evidence this distinction, here is a thought experiment: what if human language did a better job at compressing communications, much like our computers do with most of our digital communications? Then language would be no less meaningful, yet it would lack any intrinsic statistical structure, thus making it impossible to learn a language model like we just did.
#
# ## Take aways
# * We can generate discrete sequence data by training a model to predict the next tokens(s) given previous tokens.
# * In the case of text, such a model is called a "language model" and could be based on either words or characters.
# * Sampling the next token requires balance between adhering to what the model judges likely, and introducing randomness.
# * One way to handle this is the notion of softmax temperature. Always experiment with different temperatures to find the "right" one.

# %%
est.shutdown()
stop_orca_context()
# Out:
# Stopping orca context
